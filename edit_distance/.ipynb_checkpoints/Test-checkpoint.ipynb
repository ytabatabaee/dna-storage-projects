# %%
import numpy as np
import editdistance

# %%
EXP = 100000 #number of experiments
k = 2 #size of the alphabet
length = 10
N = 5 #number of reads
ed = 3
p = 0.1 # probability of error
alphabet = ['0','1','2','3']

# %%
def noisyread(s,p):
    noisestring = ""
    for i in s:
        rand = random.randint(1,1000000)
        if rand<(1-p)*1000000:
            #no error
            noisestring += i
        elif rand < ((1-p) + p/3)*1000000:
            #substituition
            noisestring += str((random.randint(1,k-1)+int(i))%k)
        elif rand < ((1-p) + p/3 + p/3)*1000000:
            #insertion
            noisestring += str(random.randint(0,k-1))
            noisestring += i 
            #noisestring += str(random.randint(0,k-1))
        #deletion
    return noisestring

# %%
def noisyread(s,p):
    noisestring = ""
    for i in s:
        rand = random.randint(1,1000000)
        if rand<(1-p)*1000000:
            #no error
            noisestring += i
        elif rand < ((1-p) + p/3)*1000000:
            #substituition
            noisestring += str((random.randint(1,k-1)+int(i))%k)
        elif rand < ((1-p) + p/3 + p/3)*1000000:
            #insertion
            noisestring += str(random.randint(0,k-1))
            noisestring += i 
            #noisestring += str(random.randint(0,k-1))
        #deletion
    return noisestring

# %%
import editdistance
import random
import itertools
import multiprocessing as mp
import matplotlib.pyplot as plt

k = 2 #size of the alphabet
length = 12
alphabet = ['0','1','2','3']

outputs = []
for i in list(itertools.product(alphabet[:k], repeat=length)):
    outputs.append("".join(m for m in i))
random.shuffle(outputs)
filename = 'edit_scaled'
skews = [0] * 11

for ed in range(1, 12):
    pos = [0] * length
    count = 0
    for s in outputs:
        neighbors = []
        for o in outputs:
            if editdistance.eval(o, s) <= ed: # convert this to <= and it will give the less error
                neighbors.append(o)
        for n in neighbors:
            for letter in range(len(s)):
                if n[letter] != s[letter] :
                    pos[letter] += 1
        count += len(neighbors)    
    skews[ed-1] = max([p / count for p in pos]) - min([p / count for p in pos])    
    plt.plot([p / count for p in pos], label = 'ed' + str(ed))                

plt.ylabel('error')
plt.legend()
plt.title('edit distance error distribution of binary strings with length 10')
plt.savefig(filename)

# %%
plt.plot(range(2, 12), skews[1:11])

# %%
skews
# Out:
# [0.0,
#  0.09697667162382839,
#  0.0970513020005277,
#  0.06287943649108085,
#  0.027101547637358447,
#  0.007368461652667857,
#  0.0012085183102109043,
#  0.0001120000382905939,
#  4.5320054398168e-06,
#  0.0,
#  0.0]

# %%
import editdistance
import random
import itertools
import multiprocessing as mp
import matplotlib.pyplot as plt

k = 2 #size of the alphabet
length = 10
alphabet = ['0','1','2','3']

outputs = []
for i in list(itertools.product(alphabet[:k], repeat=length)):
    outputs.append("".join(m for m in i))
random.shuffle(outputs)
filename = 'hamming_scaled'


for ed in range(1, 10):
    pos = [0] * length
    count = 0
    for s in outputs:
        neighbors = []
        for o in outputs:
            if distance.hamming(o, s) == ed:
                neighbors.append(o)
        for n in neighbors:
            for letter in range(len(s)):
                if n[letter] != s[letter] :
                    pos[letter] += 1
        count += len(neighbors)    
    plt.plot([p / count for p in pos], label = 'ed' + str(ed))                

plt.ylabel('error')
plt.legend()
plt.title('hammming distance error distribution of binary strings with length 10')
plt.savefig(filename)

# %%
! pip install Distance
# Out:
# Collecting Distance
#   Using cached Distance-0.1.3.tar.gz (180 kB)
# Building wheels for collected packages: Distance
#   Building wheel for Distance (setup.py): started
#   Building wheel for Distance (setup.py): finished with status 'done'
#   Created wheel for Distance: filename=Distance-0.1.3-py3-none-any.whl size=16265 sha256=0cad51cbc615da0bd6ebb037d4088d53e947faea6d9d7d6154daa016c6ab8b61
#   Stored in directory: c:\users\y.tabatabaee\appdata\local\pip\cache\wheels\b2\10\1b\96fca621a1be378e2fe104cfb0d160bb6cdf3d04a3d35266cc
# Successfully built Distance
# Installing collected packages: Distance
# Successfully installed Distance-0.1.3
# WARNING: You are using pip version 20.2.1; however, version 20.2.4 is available.
# You should consider upgrading via the 'c:\users\y.tabatabaee\appdata\local\programs\python\python37\python.exe -m pip install --upgrade pip' command.

# %%
import distance

# %%
import editdistance
import random
import itertools
import multiprocessing as mp
import matplotlib.pyplot as plt

k = 2 #size of the alphabet
length = 10
alphabet = ['0','1','2','3']

outputs = []
for i in list(itertools.product(alphabet[:k], repeat=length)):
    outputs.append("".join(m for m in i))
random.shuffle(outputs)
filename = 'edit'

for ed in range(2, 9):
    pos = [0]*length
    for s in outputs:
        neighbors = []
        for o in outputs:
            if distance.levenshtein(o, s) == ed:
                neighbors.append(o)
        for n in neighbors:
            for letter in range(len(s)):
                if n[letter] != s[letter] :
                    pos[letter] += 1
    
    maxp = max(pos)
    minp = min(pos)
    plt.plot([(p - minp) / (maxp - minp) for p in pos], label = 'ed' + str(ed))      

plt.ylabel('error')
plt.legend()
plt.title('Pairwise error curve of binary strings with length 10 - edit distance')
plt.savefig(filename)

# %%
import editdistance
import random
import itertools
import multiprocessing as mp
import matplotlib.pyplot as plt

k = 2 #size of the alphabet
length = 10
alphabet = ['0','1','2','3']

outputs = []
for i in list(itertools.product(alphabet[:k], repeat=length)):
    outputs.append("".join(m for m in i))
random.shuffle(outputs)
filename = 'hamming'

for ed in range(2, 9):
    pos = [0]*length
    for s in outputs:
        neighbors = []
        for o in outputs:
            if distance.hamming(o, s) == ed:
                neighbors.append(o)
        for n in neighbors:
            for letter in range(len(s)):
                if n[letter] != s[letter] :
                    pos[letter] += 1
    
    plt.plot(pos, label = 'ed' + str(ed))      

plt.ylabel('error')
plt.legend()
plt.title('Pairwise error curve of binary strings with length 10 - hamming distance')
plt.savefig(filename)

# %%
import editdistance
import random
import itertools
import multiprocessing as mp
import matplotlib.pyplot as plt

k = 2 #size of the alphabet
length = 10
alphabet = ['0','1','2','3']

outputs = []
for i in list(itertools.product(alphabet[:k], repeat=length)):
    outputs.append("".join(m for m in i))
random.shuffle(outputs)
filename = 'edit'

for side in range(4, 0, -1):
    outputs = []
    for i in list(itertools.product(alphabet[:k], repeat=length)):
        outputs.append("".join(m for m in i))
    random.shuffle(outputs)
    

for ed in range(2, 9):
    pos = [0]*length
    for s in outputs:
        neighbors = []
        for o in outputs:
            if distance.levenshtein(o, s) == ed:
                neighbors.append(o)
        for n in neighbors:
            for letter in range(len(s)):
                if n[letter] != s[letter] :
                    pos[letter] += 1
    
    maxp = max(pos)
    minp = min(pos)
    plt.plot([(p - minp) / (maxp - minp) for p in pos], label = 'ed' + str(ed))      

plt.ylabel('error')
plt.legend()
plt.title('Pairwise error curve of binary strings with length 10 - edit distance')
plt.savefig(filename)

# %%
import editdistance
import random
import itertools
import multiprocessing as mp
import matplotlib.pyplot as plt

k = 2 #size of the alphabet
length = 10
alphabet = ['0','1','2','3']

outputs = []
for i in list(itertools.product(alphabet[:k], repeat=length)):
    outputs.append("".join(m for m in i))
random.shuffle(outputs)
filename = 'edit'

for side in range(4, 0, -1):
    outputs = []
    for i in list(itertools.product(alphabet[:k], repeat=length)):
        outputs.append("".join(m for m in i))
    random.shuffle(outputs)
    

for ed in range(1, 11):
    pos = [0]*(length+1)
    for s in outputs:
        neighbors = []
        for o in outputs:
            if editdistance.eval(o, s) == ed:
                neighbors.append(o)
        for n in neighbors:
            h = distance.hamming(o, s)
            pos[h] += 1  
    maxp = max(pos)
    minp = min(pos)
    plt.plot(pos, label = 'ed' + str(ed))      

plt.ylabel('pair count')
plt.legend()
plt.title('Distribution of hamming distance with respect to edit distance')
plt.savefig(filename)

# %%
import editdistance
import random
import itertools
import multiprocessing as mp
import matplotlib.pyplot as plt

k = 2 #size of the alphabet
length = 10
alphabet = ['0','1','2','3']

outputs = []
for i in list(itertools.product(alphabet[:k], repeat=length)):
    outputs.append("".join(m for m in i))
random.shuffle(outputs)
filename = 'ham'

for side in range(4, 0, -1):
    outputs = []
    for i in list(itertools.product(alphabet[:k], repeat=length)):
        outputs.append("".join(m for m in i))
    random.shuffle(outputs)
    

for ed in range(1, 11):
    pos = [0]*(length+1)
    for s in outputs:
        neighbors = []
        for o in outputs:
            if distance.hamming(o, s) == ed:
                neighbors.append(o)
        for n in neighbors:
            h = editdistance.eval(o, s)
            pos[h] += 1  
    maxp = max(pos)
    minp = min(pos)
    plt.plot(pos, label = 'hd' + str(ed))      

plt.ylabel('pair count')
plt.legend()
plt.title('Distribution of edit distance with respect to hamming distance')
plt.savefig(filename)
